# %% [markdown]
# 📝 curl 轉換成 requests 的說明
# 🔄 轉換要點：
# HTTP 方法：curl -d 表示發送 POST 請求，所以使用 requests.post()
#
# URL：直接使用相同的 URL
#
# 資料格式：
#
# curl -d 後面的 JSON 資料變成 Python 字典
# 使用 json=data 參數自動處理 Content-Type 和 JSON 編碼
# 🎯 兩種主要方法：
# 方法1（推薦）：使用 json 參數
#
# response = requests.post(url, json=data)
# 方法2：使用 data 參數 + 手動 JSON 編碼
#
# response = requests.post(url, data=json.dumps(data), headers={'Content-Type': 'application/json'})
# ⚠️ 注意事項：
# 確保目標伺服器正在運行
# 檢查網路連線
# 處理可能的錯誤狀況

# %%
import requests
import json

url ='http://localhost:11434/api/generate'

data={
    "model": "gemma3:1b", 
    "prompt":"天空為什麼是藍的?" }
#requests.post中url為引數值的呼叫
#requests.post(url,None,data)
#requests.post中url為引數名稱的呼叫
response = requests.post(url,data=json.dumps(data))
#response = requests.post(url, json=data)

#print(type(response))

if response.status_code == 200:
    print("下載成功")
    print("回傳文字",response.text)
else:
    print("下載失敗")
# Out:
# 下載成功
# 回傳文字 {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.3253303Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.4023897Z","response":"之所以","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.4790837Z","response":"是","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.4932905Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5015435Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.509218Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5181398Z","response":"主要","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5262811Z","response":"歸","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5348331Z","response":"功","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5429416Z","response":"於","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5516657Z","response":"一種","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5613124Z","response":"叫做","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5684943Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5766838Z","response":"瑞","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5851649Z","response":"利","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.5926751Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6011444Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6093026Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6183645Z","response":"現象","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6259763Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6346787Z","response":"以下","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6424821Z","response":"是","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6512526Z","response":"更","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6601289Z","response":"詳細","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6684775Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6763188Z","response":"解釋","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6857776Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.6930274Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7007369Z","response":"1","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.707388Z","response":".","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7139485Z","response":" **","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7203593Z","response":"太陽","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7273947Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7348827Z","response":"中的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7417162Z","response":"紫外線","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7501034Z","response":"和","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7571328Z","response":"紅","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7639547Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7716263Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7787328Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7872089Z","response":" ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.7945438Z","response":"太陽","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8015832Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8084496Z","response":"其實","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8163194Z","response":"包含","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8238687Z","response":"各種","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8305041Z","response":"顏","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8380276Z","response":"色的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8448377Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8511705Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8605825Z","response":"但","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8677902Z","response":"大部分","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8745335Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8830857Z","response":"能量","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.89004Z","response":"集中","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.8974931Z","response":"在","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9050216Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9120546Z","response":"色","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9185905Z","response":"和","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9249682Z","response":"紅色","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9329911Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.940169Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9473781Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9544611Z","response":"2","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9619576Z","response":".","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.968598Z","response":" **","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9750747Z","response":"空氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9858214Z","response":"中的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9903303Z","response":"微","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:45.9974836Z","response":"小","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0040309Z","response":"粒子","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0107974Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0182317Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0248855Z","response":" 我們","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0330437Z","response":"呼吸","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0403346Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0473934Z","response":"空氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0544392Z","response":"中","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0609874Z","response":"充滿","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0685062Z","response":"了","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0748102Z","response":"各種","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0847583Z","response":"微","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.0931669Z","response":"小的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1009955Z","response":"粒子","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1076817Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1151487Z","response":"例如","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.122637Z","response":"氮","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1298903Z","response":"氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1366425Z","response":"和","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1429313Z","response":"氧","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1503137Z","response":"氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1572078Z","response":"分子","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1656443Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1727277Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1815783Z","response":"3","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1873696Z","response":".","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.1939545Z","response":" **","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2006727Z","response":"瑞","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2082949Z","response":"利","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2165561Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2237268Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2317489Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2391693Z","response":" 當","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.246667Z","response":"太陽","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2535106Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2601319Z","response":"進入","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.267763Z","response":"地球","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2747527Z","response":"大","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2854025Z","response":"氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2919827Z","response":"層","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.2987982Z","response":"時","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3048749Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3114259Z","response":"會","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3190595Z","response":"與","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3267503Z","response":"這些","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3343271Z","response":"微","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3405184Z","response":"小","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3486688Z","response":"粒子","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.35632Z","response":"碰撞","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3627505Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3693463Z","response":"  ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3769024Z","response":"瑞","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3847605Z","response":"利","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3909228Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.3973672Z","response":"是一種","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4046156Z","response":"現象","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4113496Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4185791Z","response":"它","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4251458Z","response":"使得","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4329454Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4398165Z","response":"發生","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4466888Z","response":"偏","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4561433Z","response":"轉","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4627878Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4699312Z","response":"但","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4769239Z","response":"波","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4849456Z","response":"長","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4922972Z","response":"不同","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.4998728Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5080388Z","response":"  ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5159106Z","response":"\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5231083Z","response":"   ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5293551Z","response":"*","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5364957Z","response":"  ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5430713Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5498476Z","response":"色的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.558474Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5663296Z","response":"波","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5734789Z","response":"長","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.584137Z","response":"較","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5901771Z","response":"短","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.5995158Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6067953Z","response":"更容易","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6136538Z","response":"被","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6207375Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6268423Z","response":"掉","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6339399Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6411885Z","response":"\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6495554Z","response":"   ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6563258Z","response":"*","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6631253Z","response":"  ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6713722Z","response":"紅","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.680534Z","response":"色的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6856418Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.692634Z","response":"波","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.6998899Z","response":"長","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7068165Z","response":"較","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7143938Z","response":"長","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7218503Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7294422Z","response":"更容易","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7361329Z","response":"穿","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7435912Z","response":"過","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7500358Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7571359Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7649334Z","response":"4","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7717823Z","response":".","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7802975Z","response":" **","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7876807Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.7966134Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8043991Z","response":"傳","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8108853Z","response":"播","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8180756Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8243636Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8320476Z","response":" ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8392153Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8478718Z","response":"過程中","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8549771Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8607419Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8684014Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8758978Z","response":"被","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8835187Z","response":"分散","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8901396Z","response":"到","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.8980139Z","response":"整個","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9050286Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9120221Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9188677Z","response":"就像","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9251835Z","response":"陽","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9324494Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.938804Z","response":"灑","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.948403Z","response":"在","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9549171Z","response":"水","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.96379Z","response":"面上","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9713513Z","response":"一樣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9776014Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9856659Z","response":"讓","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.9918675Z","response":"我們的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:46.999064Z","response":"眼睛","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0060971Z","response":"看到","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0132194Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0206649Z","response":"呈現","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0282896Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0369429Z","response":"色","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0432775Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0502064Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0570343Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0649141Z","response":"簡單","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0716932Z","response":"來說","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0806236Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0866795Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.0964028Z","response":"是","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1041303Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.110283Z","response":"色的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1175461Z","response":"是因為","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1244828Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1327761Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1398915Z","response":"更容易","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1473508Z","response":"被","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1551932Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.163335Z","response":"掉","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1713517Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1780979Z","response":"所以","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1853074Z","response":"我們","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.191831Z","response":"看到","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.1988213Z","response":"的天","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2066087Z","response":"空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2140516Z","response":"是","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2215064Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2279006Z","response":"色的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2350936Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2428962Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.249533Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2560104Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2648146Z","response":"需要","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2708793Z","response":"注意的是","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.284089Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2910686Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.2975791Z","response":"的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3050517Z","response":"顏色","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3131273Z","response":"會","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.320245Z","response":"根據","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3280485Z","response":"時間","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3350942Z","response":"和","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3417489Z","response":"地點","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3482135Z","response":"而","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3553079Z","response":"變化","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3640668Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3712895Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3796723Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.3870392Z","response":"*","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.394043Z","response":"   ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.400572Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4075299Z","response":"日","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4151406Z","response":"出","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4220999Z","response":"和","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.428566Z","response":"日","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4358082Z","response":"落","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4432983Z","response":"時","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4506197Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4567287Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4643241Z","response":" ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.471439Z","response":"太陽","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4802625Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.486906Z","response":"穿","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.4950766Z","response":"過","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5052129Z","response":"大","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5138595Z","response":"氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5202554Z","response":"層","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5276002Z","response":"時","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.53486Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5416392Z","response":"更多","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5496378Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5559114Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5639649Z","response":"被","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5733875Z","response":"散射","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5805493Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.5870596Z","response":"剩下","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.596325Z","response":"更多的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6034577Z","response":"紅","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6100307Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6176066Z","response":"和","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6243161Z","response":"黃","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6315111Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.63898Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6475599Z","response":"所以","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.655092Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6635214Z","response":"呈現","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6722756Z","response":"紅色","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6798499Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6876196Z","response":"\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.6961089Z","response":"*","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7037591Z","response":"   ","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7100838Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7182203Z","response":"污染","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7250705Z","response":"：","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7315819Z","response":"**","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7382926Z","response":" 空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7481126Z","response":"氣","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.754942Z","response":"中的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7632367Z","response":"污染物","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7703039Z","response":"會","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7779047Z","response":"阻","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7869496Z","response":"擋","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.7953523Z","response":"光","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8018955Z","response":"線","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8110621Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8181288Z","response":"讓","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.82631Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8338353Z","response":"變得","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8403553Z","response":"更","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8475579Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.854431Z","response":"，","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8626853Z","response":"甚至","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8694012Z","response":"變","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8784081Z","response":"為","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8863829Z","response":"黑色","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.8967526Z","response":"。","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9037723Z","response":"\n\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.912858Z","response":"希望","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9219709Z","response":"這個","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9307511Z","response":"解釋","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9377369Z","response":"能","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.944832Z","response":"幫助","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9523851Z","response":"你","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9616449Z","response":"理解","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9679866Z","response":"為什麼","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9762475Z","response":"天空","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9827607Z","response":"是","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:47.9898747Z","response":"藍","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:48.0006927Z","response":"色的","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:48.0063506Z","response":"！","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:48.0139194Z","response":"\n","done":false}
# {"model":"gemma3:1b","created_at":"2025-09-13T08:00:48.020481Z","response":"","done":true,"done_reason":"stop","context":[105,2364,107,141370,95202,237026,241339,236918,236881,106,107,105,4368,107,141370,132414,237026,241339,236918,236900,16829,242111,238093,238299,120460,100083,1018,240046,237766,150341,1018,236918,121887,236924,19697,237026,237611,43078,236918,185411,237184,108,236770,236761,5213,83700,237914,12870,222337,237206,239691,237914,237184,1018,236743,83700,237914,46078,37250,77722,242017,40074,237914,236900,237678,63647,236918,66899,50281,237075,241339,237673,237206,228715,237914,236924,108,236778,236761,5213,235450,12870,238477,237369,166747,237184,1018,95398,77816,236918,235450,237103,184822,237089,77722,238477,74517,166747,236900,34313,243140,239471,237206,240514,239471,67845,236924,108,236800,236761,5213,240046,237766,150341,237184,1018,161534,83700,237914,82655,71216,237110,239471,239614,237479,236900,238003,238693,52426,238477,237369,166747,181044,236924,138,240046,237766,150341,192922,121887,236900,238010,60138,237914,90972,239759,240002,236900,237678,238663,237953,15497,236924,138,107,139,236829,138,241339,40074,237914,238663,237953,239350,238906,236900,186897,237759,150341,239590,236924,107,139,236829,138,239691,40074,237914,238663,237953,239350,237953,236900,186897,239409,238124,236924,108,236812,236761,5213,150341,236918,239878,239104,237184,1018,236743,150341,210947,236900,241339,237914,237759,131744,237238,117908,141370,236900,55326,240133,237914,245343,237075,237556,237360,56727,239022,236900,239301,84912,58229,20748,141370,150701,241339,237673,236924,108,1018,74624,94757,236900,141370,237026,241339,237673,15093,27502,241339,237914,186897,237759,150341,239590,236900,12442,13125,20748,101251,237903,237026,241339,40074,236924,1018,108,1018,10042,191627,236900,141370,236918,158519,238003,99647,13413,237206,222498,237521,170134,237184,1018,108,236829,139,1018,237205,237191,237206,237205,238468,237479,237184,1018,236743,83700,237914,239409,238124,237110,239471,239614,237479,236900,24894,241339,237914,237759,150341,236900,180986,68246,239691,237914,237206,240544,237914,236900,12442,141370,150701,228715,236924,107,236829,139,1018,68509,237184,1018,84853,239471,12870,191330,238003,240172,244968,237914,238448,236900,239301,141370,172150,237611,241339,236900,28584,239610,237873,73199,236924,108,21226,17161,185411,237230,116904,237408,29666,95202,141370,237026,241339,40074,237354,107],"total_duration":2984353300,"load_duration":207583400,"prompt_eval_count":15,"prompt_eval_duration":80020500,"eval_count":342,"eval_duration":2695914700}

# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T07:41:44.9777706Z', 'response': '{ \n    "解釋：":\n    "Python 的函式就像是小程式，它們能做一些特定的事情。 就像一個指令，你可以告訴它要怎麼做。",\n    "它們會自動處理一些步驟，例如：”, ，“計算，顯示，讀取資料，等等。”, ，“你不需要特別注意，它們會自己處理好。”, ，“你可以重複使用這些函式，這樣可以避免寫重複的程式碼。”, ，“這樣，你可以寫出很多程式，但只要程式碼有函式，就已經夠了。”, ，“就像一個工具，你可以用它來做不同的事情。” ，“簡單來說，函式就是 Python 程式的“指令”。":\n    " 舉個例子：”, “ `print(" \t\t\t\t\t\t\t\t\t  \t\t\t\t\t\t\t\t\t  \n                                                  \t\t\t\t\t\t\t\t\t  \n                                                  \t\t\t\t\t\t\t\t\t  \n                                                  \t\t\t\t\t\t\t\t\t  \n                                                  \t\t\t\t\t\t\t\t\t  \n                                                  \t\t\t\t\t\t\t\t\t  \n', 'done': False}
# {
#     "解釋：":
#     "Python 的函式就像是小程式，它們能做一些特定的事情。 就像一個指令，你可以告訴它要怎麼做。",
#     "它們會自動處理一些步驟，例如：”, ，“計算，顯示，讀取資料，等等。”, ，“你不需要特別注意，它們會自己處理好。”, ，“你可以重複使用這些函式，這樣可以避免寫重複的程式碼。”, ，“這樣，你可以寫出很多程式，但只要程式碼有函式，就已經夠了。”, ，“就像一個工具，你可以用它來做不同的事情。” ，“簡單來說，函式就是 Python 程式的“指令”。":
#     " 舉個例子：”, “ `print("

# %% [markdown]
# 模型的超參數 "temperature"、"top_p" 和 "top_k" 是控制生成文字隨機性和多樣性的重要參數：
#
# - **temperature (溫度)**：
#   控制模型選擇下個詞的隨機程度。數值越低（接近0），輸出越穩定、保守，模型傾向選擇機率最高的詞。數值越高（如0.7），生成的詞彙越多樣且富有創造性，會冒險選擇較少見的詞彙。
#
# - **top_p (核采樣，Nucleus Sampling)**：
#   是一種根據累積機率質量動態選擇候選詞集合的方法。模型會從機率加總達到 top_p（常見值約0.9）的一組詞彙中，隨機抽取下一個詞。這可以去除機率極低的詞彙，使生成更精煉且多樣。
#
# - **top_k (前K取樣)**：
#   模型僅從機率最高的 k 個詞彙中挑選下一個詞。比方說 top_k=50，代表只會從機率排名前50的詞彙中選擇。它透過限制詞彙範圍來控制生成多樣性。
#
# 總結：
# - temperature 控制生成的創造力與隨機性強弱。
# - top_p 動態篩選高機率詞集合，去除長尾低機率詞。
# - top_k 固定篩選最高機率詞的數量，用於限制候選範圍。
#
# 這些參數可以單獨使用，也可以組合調整，依應用需求調節生成文字的多樣性與穩定性.[1][2][3][4]
#
# [1](https://blog.miniasp.com/post/2024/05/21/LLM-Temperature-Top-P-Nucleus-Sampling-Top-K)
# [2](https://www.cnblogs.com/frankcui/p/18671142)
# [3](https://www.toolify.ai/tw/ai-news-tw/llm-%E4%B8%AD%E7%9A%84%E6%BA%AB%E5%BA%A6top-ptop-k-%E6%98%AF%E4%BB%80%E9%BA%BC%E5%BE%9E%E6%A6%82%E5%BF%B5%E5%88%B0%E4%BB%A3%E7%A2%BC-968155)
# [4](http://tinywell.com/2024/05/15/llm-params/)
# [5](https://blog.csdn.net/a1920993165/article/details/134691021)
# [6](https://vocus.cc/article/665ee3e9fd89780001ad34ed)
# [7](https://blog.csdn.net/qq_43243579/article/details/136331123)
